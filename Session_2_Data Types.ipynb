# %%
Salary=100000
tax_percentage=10
tax_amount=Salary*tax_percentage/100
tax_amount
# Out:
# 10000.0

# %% [markdown]
# #Data types (In built data types) (SPECIAL ONES THESE ARE)
# - int
#
# - float
#
# - complex
#
# - str
#
# - list
#
# - tuple
#
# - dict
#
# - set
#
# - frozenset
#
# - range
#
# - bytes
#
# - bytearray
#
# - memoryview
#
# - bool

# %% [markdown]
# **interger data type**

# %%
number=100
type(number)
# Out:
# int

# %% [markdown]
# **float data type**

# %%
n1=10.5
type(n1)
# Out:
# float

# %% [markdown]
# **Exponential Representation***

# %%
print(1e1) #1*10
print(1e2) #1*100
print(2e3) #2*1000
# Out:
# 10.0
# 100.0
# 2000.0

# %%
print(1e1,1e+1)
print(1e2,1e+2)
print(2e3,2e+3)
# Out:
# 10.0 10.0
# 100.0 100.0
# 2000.0 2000.0

# %%
2e3  #2*<number 3 zeros> 2*10^3
1e1 #1*10^1
2e1 #2*10*1
1e2 #1*10^2 10*10=100

# %%
print(1e+1) #1*10
print(1e-1) #1/10
# Out:
# 10.0
# 0.1

# %%
2e+3 #2*1000
2e-3 #2/1000

# %% [markdown]
# **String**

# %%
name='naresh it '
institute_name='naresh it'
coaching_center='naresh it'
name
# Out:
# 'naresh it '

# %%
print(name)
print(institute_name)
print(coaching_center)
# Out:
# naresh it
# naresh it
# naresh it

# %%
print(name)
# Out:
# naresh it

# %%
print(institute_name)
# Out:
# naresh it

# %%
print(coaching_center)
# Out:
# naresh it

# %%
name
# Out:
# 'naresh it '

# %%
greet1='hello'
greet2='hello'
len(greet1),len(greet2)
# Out:
# (5, 5)

# %%
greet1='hello'
greet2='hello                  '
greet1,greet2
# Out:
# ('hello', 'hello                  ')

# %%
print(greet1)
# Out:
# hello

# %%
print(greet2)
# Out:
# hello

# %% [markdown]
# **Double Quotes**

# %%
name1="Hyderabad"
#single and double quotes both are same
name1
# Out:
# 'Hyderabad'

# %%
print(name1)
# Out:
# Hyderabad

# %%
s1=" I Joined in DS and AI Class "  #works
s2= I joined in 'DS and AI' Class    #fails

#above statement is a information
#information in english
#red color ====> quotes
# single or double
# Out:
#   Cell In[33], line 2
#     s2= I joined in 'DS and AI' Class    #fails
#           ^
# SyntaxError: invalid syntax

# %%
s1=" I Joined in DS and AI Class "  #works
s2= 'I joined in DS and AI Class ' #works
print(s1,s2)
# Out:
#  I Joined in DS and AI Class  I joined in DS and AI Class

# %%
s1=" I Joined in DS and AI Class "  #works
s2= 'I joined in DS and AI Class ' #works
(s1,s2)
# Out:
# (' I Joined in DS and AI Class ', 'I joined in DS and AI Class ')

# %%
s1=" I Joined in 'DS and AI 'Class " 
print(s1)
# Out:
#  I Joined in 'DS and AI 'Class

# %%
s1= 'I Joined in "DS and AI "Class '
print(s1)
s1
# Out:
# I Joined in "DS and AI "Class
# 'I Joined in "DS and AI "Class '

# %%
s1= 'I Joined in "DS and AI "Class '
s1
# Out:
# 'I Joined in "DS and AI "Class '

# %% [markdown]
# **triple quoutes**
#
# - In jupuyter notebook we have a **markdown** option to write a information
#
# - **markdown** means we are conveying some information to the user
#
# - but in other platform like **vs code pycharm** we dont have markdown option
#
# - we can convey the information using **triple quotes**
#
# - this is also called as **Doc String**
#
# - The code part we can provide single or dobule quotes
#
# - But conveying the information about the code is triple quotes
#
# - **triple quotes** are used in the prompt engineering

# %%
# """"
# triple quoutes

# - In jupuyter notebook we have a **markdown** option to write a information

# - **markdown** means we are conveying some information to the user

# - but in other platform like **vs code pycharm** we dont have markdown option

# - we can convey the information using **triple quotes**

# - this is also called as **Doc String**

# - The code part we can provide single or dobule quotes 

# - But conveying the information about the code is triple quotes 
# """

# %% [markdown]
# **Boolean**
#
# - When we ask the question to machine
#
# - Machine always provide only two answers
#
#   - True
#   - False
#
# - True means 1
#
# - False means 2
#
# - You can think it another way True mean ON False means OFF

# %%
on=True
type(on)
# Out:
# bool

# %%
off=False
type(off)
# Out:
# bool

# %%
True=10
'True'=true
'true'=True
true
# Out:
#   Cell In[6], line 1
#     True=10
#     ^
# SyntaxError: cannot assign to True
