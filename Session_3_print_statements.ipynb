# %%
Name='I am someshwar'
age='25 years old'
place='coming from hyderabad'
print('my name is python Im 10 year old.I came from hyderabd')

# %%
n1=100
n2=200
add=n1+n2
print('the addition of 100 and 200 is 300')
print('the addition of {} and {} is {}')
print('the addition of {} and {} is {}'.format(n1,n2,add))
# Out:
# the addition of 100 and 200 is 300
# the addition of {} and {} is {}
# the addition of 100 and 200 is 300

# %%
name='someshwar'
age='25'
place='hyderabad'
print('my name is someshwar Im 25 year old.I came from hyderabd')
print('my name is {} I am {} year old .I came from {}')
print('my name is {} I am {} year old .I came from {}'.format(name,age,place))
# Out:
# my name is someshwar Im 25 year old.I came from hyderabd
# my name is {} I am {} year old .I came from {}
# my name is someshwar I am 25 year old .I came from hyderabad

# %% [markdown]
# **f-string**
# - Very easiest method and most used method

# %%
n1=100
n2=200
add=n1+n2
print('the addition of 100 and 200 is 300')
print(f'the addition of {n1} and {n2} is {add}')
# Out:
# the addition of 100 and 200 is 300
# the addition of 100 and 200 is 300

# %%
name='someshwar'
age='25'
place='hyderabad'
print('my name is someshwar Im 25 year old.I came from hyderabd')
print(f'my name is {name} Im {age} year old.I came from {place}')
# Out:
# my name is someshwar Im 25 year old.I came from hyderabd
# my name is someshwar Im 25 year old.I came from hyderabad

# %%
n1=100
n2=200
sub=n1-n2
print(f'the subtraction of {n1} and {n2} is {sub}' )
mul=n1*n2
print(f'the multiplication of {n1} and {n2} is {mul}' )
div=n1/n2
print(f'the division of {n1} and {n2} is {div}' )
# Out:
# the subtraction of 100 and 200 is -100
# the multiplication of 100 and 200 is 20000
# the division of 100 and 200 is 0.5

# %%
n1=100
n2=200
sub=n1-n2
print('the subtraction of {} and {} is {}'.format(n1,n2,sub))
mul=n1*n2
print('the multiplication of {} and {} is {}'.format(n1,n2,mul) )
div=n1/n2
print('the division of {} and {} is {}'.format(n1,n2,div) )
# Out:
# the subtraction of 100 and 200 is -100
# the multiplication of 100 and 200 is 20000
# the division of 100 and 200 is 0.5

# %%
# area of circle pie*r*r
radius=5
pie=3.14
area_of_circle=pie*radius*radius
print(f'area of circle is : {area_of_circle}')
print('area of circle is {}'.format(area_of_circle))
# Out:
# area of circle is : 78.5
# area of circle is 78.5

# %%
height_of_the_triangle = 5
breadth_of_triangle = 10
area_of_triangle=0.5*height_of_the_triangle*breadth_of_triangle
print(f'area of triangle is {area_of_triangle})')
print('area of triangle is {}'.format(area_of_triangle))
# Out:
# area of triangle is 25.0)
# area of triangle is 25.0

# %%
n1=1222
n2=1222
n3=1222
average=(n1+n2+n3)/3
print(f'average of three given numbers is : {average}')
print('average of {} ,{} and {} is {}'.format(n1,n2,n3,average))
# Out:
# average of three given numbers is : 1222.0
# average of 1222 ,1222 and 1222 is 1222.0

# %% [markdown]
# **Mistakes**

# %%
height_of_the_triangle = 5
breadth_of_triangle = 10
area_of_triangle=0.5*height_of_the_triangle*breadth_of_triangle
print(
# Out:
#   Cell In[18], line 4
#     print(
#           ^
# _IncompleteInputError: incomplete input

# %%
height_of_the_triangle = 5
breadth_of_triangle = 10
area_of_triangle=0.5*height_of_the_triangle*breadth_of_triangle
print(f'average of three given numbers is : {average})
# Out:
#   Cell In[19], line 4
#     print(f'average of three given numbers is : {average})
#           ^
# SyntaxError: unterminated f-string literal (detected at line 4)

# %%
print(')
# Out:
#   Cell In[20], line 1
#     print(')
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
radius=5
pie=3.14
area_of_circle=pie*radius*radius
print(f'area of circle is : {area_of_circel}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 4
#       2 pie=3.14
#       3 area_of_circle=pie*radius*radius
# ----> 4 print(f'area of circle is : {area_of_circel}')
#
# NameError: name 'area_of_circel' is not defined

# %%
radius=5
pie=3.14
area_of_circle=pie*radius*radius
print(f'area of circle is : {area_of_circle}')
print('area of circle is {}'.fomat(area_of_circle))
# Out:
# area of circle is : 78.5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 5
#       3 area_of_circle=pie*radius*radius
#       4 print(f'area of circle is : {area_of_circle}')
# ----> 5 print('area of circle is {}'.fomat(area_of_circle))
#
# AttributeError: 'str' object has no attribute 'fomat'

# %%
bill_amount=50000
tip_amount=1000
total_bill_amount=bill_amount+tip_amount
print(f'total bill amount including tip is : {total_bill_amount}')
print('total bill amount including tip is : {}'.format(total_bill_amount))
# Out:
# total bill amount including tip is : 51000
# total bill amount including tip is : 51000

# %% [markdown]
# **round**

# %%
round(10.4321)
# Out:
# 10

# %%
round(10.6789)
# Out:
# 11

# %%
round(10.6789,1)
# 1 indicates after decimal only one digit
# 6789===7000===7
#10.7
# Out:
# 10.7

# %%
round(10.6789,2)
# 2 indicares after decimal only two digits
# 789===800==8
# 10.68
# Out:
# 10.68

# %%
n1=1222
n2=1222
n3=1222
average=(n1+n2+n3)/3
round_of_average=round(average,2)
print(f'average of three given numbers is : {round_of_average}')
print('average of {} ,{} and {} is {}'.format(n1,n2,n3,average))
# Out:
# average of three given numbers is : 1222.0
# average of 1222 ,1222 and 1222 is 1222.0

# %%
n1=1222
n2=1222
n3=1220
average=(n1+n2+n3)/3
round(average,3)
# Out:
# 1221.333

# %% [markdown]
# - In built fucntions are
#  -print()
#  -type()
#  -max()
#  -min()
#  -len()
#  -round()

# %%
# () function call method
# whetever we miss the bracket
# it will indicates two ways

# %% [markdown]
# - bound method
#
# - function

# %%
import os
os.getcwd
# then recall we missed brackets
# Out:
# <function nt.getcwd()>

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\user\\Documents\\NareshIT\\python_sessions'

# %%
 name='python' #hard coded
# we fixed the value 
# we need to ask the user enter any value
# different users can use the same code

# %% [markdown]
# **input**

# %%
input ## bound method will get output becz we didnt write the ()
# Out:
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x000001FEC2BE1160>>

# %%
input()
# Out:
#  python
# 'python'

# %%
input()
# Out:
#  30
# '30'

# %%
input()
# Out:
#  hyderabad
# 'hyderabad'

# %%
input()
# Out:
#  pincode 500018
# 'pincode 500018'

# %%
input()
input()
input()
# Out:
#  Someshwar
#  25 years
#  Hyderabad
# 'Hyderabad'

# %%
name=input()
# Out:
#  someshwar

# %%
name
# Out:
# 'someshwar'

# %%
age=input()
# Out:
#  25

# %%
print(age)
# Out:
# 25

# %%
name=input()
age=input()
city=input()
print(f'my name is {name} ,my age is {age} ,I am came from {city}')
# Out:
#  someshwar
#  25
#  hyderabad
# my name is someshwar ,my age is 25 ,I am came from hyderabad

# %%
name=input('Enter your name :')
age=input('Enter your age :')
city=input('Enter your city : ')
print(f'my name is {name} ,my age is {age} ,I am came from {city}')
# Out:
# Enter your name : someshwar
# Enter your age : 25
# Enter your city :  Hyderabad
# my name is someshwar ,my age is 25 ,I am came from Hyderabad

# %% [markdown]
# **Note**
#
# - When we provide a value from keyboard
#
# - By default pyton takes string date type

# %%
n1=input('enter a number :')
n1
# Out:
# enter a number : 2520
# '2520'

# %%
n1=input('enter a number :')
n1
# Out:
# enter a number : Two thousand five twenty
# 'Two thousand five twenty'

# %%
n1=input('enter a number 1 :')
n2=input('enter a number 2 :')
n1+n2
# Out:
# enter a number 1 : 100
# enter a number 2 : 200
# '100200'

# %% [markdown]
# **type cast**
#
#   - convert one data type to another data type
#   - int,float,str,bool
#   - if a user provide one data type we can able to convert into another data types

# %% [markdown]
# **integer to other data types**

# %%
n1=100
# 100 ===> 100.0
float(n1)
# Out:
# 100.0

# %%
n1=100
# 100 ====string===> '100'
str(n1)
# Out:
# '100'

# %%
n1=100
# 100 ===> bool====> True
bool(n1)
# Out:
# True

# %%
float(100),str(100),bool(100)
# Out:
# (100.0, '100', True)

# %%
float(-100),str(-100),bool(100)
# Out:
# (-100.0, '-100', True)

# %%
float(0),str(0),bool(0)
# Out:
# (0.0, '0', False)

# %% [markdown]
# **float to other**

# %%
int(10.5),str(10.5),bool(10.5)
# Out:
# (10, '10.5', True)

# %%
int(-10.5),str(-10.5),bool(-10.5)
# Out:
# (-10, '-10.5', True)

# %%
int(0.0),str(0.0),bool(0.0)
# Out:
# (0, '0.0', False)

# %% [markdown]
# **string to other**

# %%
s1='apple'
s2='100'
s3='100.50'

# %%
int('apple'),float('apple')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 int('apple'),float('apple')
#
# ValueError: invalid literal for int() with base 10: 'apple'

# %%
bool('apple')
# Out:
# True

# %%
int('100'),float('100'),bool('100')
# Out:
# (100, 100.0, True)

# %%
int('10.5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 int('10.5')
#
# ValueError: invalid literal for int() with base 10: '10.5'

# %%
float('10.5')
# Out:
# 10.5

# %%
int(100.5)
# Out:
# 100

# %%
int('100')
# Out:
# 100

# %%
int('100.5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 int('100.5')
#
# ValueError: invalid literal for int() with base 10: '100.5'

# %% [markdown]
# ** we can convert int('100.5') to 100 beacuse decimal we cant change or convert**

# %%
'apple' #5
'app'   #3
'ap'    #2
'p'     #1
''      #0
# Out:
# ''

# %%
int(100.5)
# Out:
# 100

# %%
bool('0')
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
int('100.5')  #error
int('100')     #100
bool('0') ## true (we can see the one character)
bool(0)   ## False
int('100.5')  vs int(100.5)
bool('0')  vs bool(0)
# Out:
#   Cell In[85], line 4
#     int('100.5')  vs int(100.5)
#                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# **Bool to other**

# %%
int(True)  #1
float(True) #1.0
str('True') # 'True'
# Out:
# 'True'

# %%
int(True)  #1
# Out:
# 1

# %%
float(True)
# Out:
# 1.0

# %%
str('True')
# Out:
# 'True'

# %%
int(False)
# Out:
# 0
